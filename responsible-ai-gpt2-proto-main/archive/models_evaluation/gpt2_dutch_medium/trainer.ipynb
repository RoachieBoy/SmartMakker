# %%
import torch
import transformers
import warnings 

from aitextgen.TokenDataset import TokenDataset
from aitextgen.aitextgen import aitextgen

model_source = "GroNLP/gpt2-medium-dutch-embeddings"
filepath_dataset = r"../evaluation_training_data/lyrics_400.csv"
num_steps = 5000

warnings.filterwarnings("ignore")

# %%
gpu_available = torch.cuda.is_available()

if gpu_available:
    torch.set_float32_matmul_precision('medium')

# %%
model = aitextgen(
    model=model_source,
    verbose=True,
    to_gpu=gpu_available,
)

tokenizer = transformers.AutoTokenizer.from_pretrained(model_source)

model.tokenizer = tokenizer
# Out:
# loading configuration file config.json from cache at aitextgen\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\config.json
# Model config GPT2Config {
#   "_name_or_path": "GroNLP/gpt2-medium-dutch-embeddings",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 1,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_inner": null,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "pad_token_id": 0,
#   "predict_special_tokens": true,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 100,
#       "no_repeat_ngram_size": 4,
#       "num_beams": 10,
#       "repetition_penalty": 10.0,
#       "temperature": 2.0,
#       "top_k": 20,
#       "top_p": 0.9
#     }
#   },
#   "transformers_version": "4.27.4",
#   "use_cache": true,
#   "vocab_size": 40000
# }
#
# loading weights file pytorch_model.bin from cache at aitextgen\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\pytorch_model.bin
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
#
# All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# All the weights of GPT2LMHeadModel were initialized from the model checkpoint at GroNLP/gpt2-medium-dutch-embeddings.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPT2LMHeadModel for predictions without further training.
# Generation config file not found, using a generation config created from the model config.
# loading configuration file config.json from cache at C:\Users\winan/.cache\huggingface\hub\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\config.json
# Model config GPT2Config {
#   "_name_or_path": "GroNLP/gpt2-medium-dutch-embeddings",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 1,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_inner": null,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "pad_token_id": 0,
#   "predict_special_tokens": true,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 100,
#       "no_repeat_ngram_size": 4,
#       "num_beams": 10,
#       "repetition_penalty": 10.0,
#       "temperature": 2.0,
#       "top_k": 20,
#       "top_p": 0.9
#     }
#   },
#   "transformers_version": "4.27.4",
#   "use_cache": true,
#   "vocab_size": 40000
# }
#
# loading file vocab.json from cache at C:\Users\winan/.cache\huggingface\hub\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\vocab.json
# loading file merges.txt from cache at C:\Users\winan/.cache\huggingface\hub\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\merges.txt
# loading file tokenizer.json from cache at C:\Users\winan/.cache\huggingface\hub\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at C:\Users\winan/.cache\huggingface\hub\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\special_tokens_map.json
# loading file tokenizer_config.json from cache at C:\Users\winan/.cache\huggingface\hub\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\tokenizer_config.json
# loading configuration file config.json from cache at C:\Users\winan/.cache\huggingface\hub\models--GroNLP--gpt2-medium-dutch-embeddings\snapshots\0ea2e72f4d0a68c02ca02e62c7f3deadc956c1e7\config.json
# Model config GPT2Config {
#   "_name_or_path": "GroNLP/gpt2-medium-dutch-embeddings",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 1,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_inner": null,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "pad_token_id": 0,
#   "predict_special_tokens": true,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 100,
#       "no_repeat_ngram_size": 4,
#       "num_beams": 10,
#       "repetition_penalty": 10.0,
#       "temperature": 2.0,
#       "top_k": 20,
#       "top_p": 0.9
#     }
#   },
#   "transformers_version": "4.27.4",
#   "use_cache": true,
#   "vocab_size": 40000
# }

# %%
model.model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(40000, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=40000, bias=False)
# )

# %%
train_data = TokenDataset(
    file_path=filepath_dataset,
    tokenizer=tokenizer,
    line_by_line=True
)
# Out:
#   0%|          | 0/396 [00:00<?, ?it/s]

# %%
model.train(
    train_data=train_data,
    seed=27,
    num_steps=num_steps,
    generate_every=100,
    output_dir=r"./output",
    freeze_layers=True,
    num_layers_freeze=10
)
# Out:
# pytorch_model.bin already exists in /./output and will be overwritten!
# Windows does not support multi-GPU training. Setting to 1 GPU.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   0%|          | 0/5000 [00:00<?, ?it/s]
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 100 steps reached: generating sample texts.
# ==========
#
#
#
#
# en ik jou wat je mij mij
#
# ik wil hier niet veel mee dat is niet schelen
#
# jij heb je alles is hier wel voor jou
#
#
#
#
#
#
#
#
# je bent
#
# de zon
#
# maar er geen is die zal
#
#
# ik vind je altijd bij het zal jou
#
#
#
# maar je niet zien wat het is er moet niet in
#
#
#
#
# ik kan dan
#
# en je geen meer met je
# ik heb je komt
#
# want je weet dat heb mij niet over
#
#
#
# wn mij geen droom
#
#
#
#
# jij moet doen
#
# ik was wel gedaan
# de zon
#
#
# en ik denk ik weet niet wat ik kan je zeggen
#
#
#
#
#
#
#
#
# de dag
#
#
#
# ik ben je me niet in jou
# het is jou
# ik wil dat je nooit meer zal ik heb mij
#
# jij bent er nooit meer heb je alles wat je zie je niet meer
#
#
# ik ben ik altijd wat ook dat is wel wat je bij mij
#
# dat je niet meer bij mij
#
# ik heb niet meer van je lief
#
# t is
#
#
#
#
#
#
#
#
#
#
#
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 200 steps reached: generating sample texts.
# ==========
#
# en je mij dat ik mijn dromen
# mn leven wat ik dit je je ik het je met mij
# ik wil me nu niet meer
# en mn beetje
# jij bent je zo van jou
# wat je wat ik het
# in het licht
# ik wil me
# ik wil ik niet wat ik wil
# ik wil je mij niet meer van ons
# het maakt mn leven
# ik wil je niet meer
# ik leef aan het lot
# en zeg ik het hart
# en je niet meer
# ik denk ik niet meer stuk
# maar ik dat ik nooit meer
# je bent
# je bent hier was haar liefde en je niet voor mij nooit meer met tranen
#
#
# ik ken je bent mijn liefde aan de wereld die je vrienden
# maar denk ik mij
# jij bent
#
# en dat ik zo veel vergeten
# we zijn
# ik wil mn leven en ik van mij
# ja het leven
# laat mij niet meer
# ik hoop dat ik zo veel van het een beetje beetje verliefd bent
# ik wil ik je bent
#
#
# je bent het nooit meer
# en ik je bent dat je nog n beetje
# ik wil ik aan mij
# ik wil je niet meer van de liefde ook nooit meer gaan
#
# nee
# ik wil
# ja het geluk
#
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 300 steps reached: generating sample texts.
# ==========
#
#
#
# of ik heb je niet
# maar ik ook met me niet
# ik wil niet voor mij alleen weer maar wat ik ook een beetje van jou
#
# en kijk heb
# ik ben al je zo
#
# als ik wil niet
# ik wil je me je weer naar je ogen
# ik wil je hou van je niet meer zo wil
# voor dat ik nu wat ik kom ik jou
# ik wil ik weer
# ik hou
# ik hou naar
# ik ben
# en je niet van jou
#
# ik wil nooit meer ben je toch niet dat ik niet op de zon maar met jou
# toch heb
# maar ik ga ik je dromen
# ik wil
# nee ik je dat jij het je
# maar ik wil je het nog een keertje je weer met alles wat je hebt
# ik voel me zo snel weer
# ik wilde ik kan
#
# ik wil ik kan
# oh ik
# ik weet
# ik wil je moet je zo graag bij je weer wat je niet
# toch ben je weet
# ik ben ik het is
# ik wil
# ik wil je ogen
#
# laat me weer
#
#
# ik wil niet meer
#
#
# ik heb je alles alleen maar een beetje meer zonder jou
# ik wil niet zonder je alleen
#
# ik heb je hebt zo
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 400 steps reached: generating sample texts.
# ==========
#  de het nog
# ik weet dat is maar
# ik ben er niet aan
# ik heb nooit
# ik wil
# dan is die jij
# al die je me niet
#
# ik
# de naam
#
#
# ik ben ik heb ik niet
# toch is
# ik wil ik al nooit uit shalala shalala
# t
#
# ik wil mij ook maar maar niet meer maar met me nooit meer
#
# ik wil ik zie ik het niet bij
# ik wil met me nog
# t geluk nog steeds
# wat wat ik de laatste
# ik wil het niet
# ik heb
#
# ik zou nu in
# het zijn
# ik weet
#
# t is de liefde
#
# ik wil ik dat ik zo klein maar mijn eigen leven maar voor mij
# maar het niet
# ik zeg me die ik wil niet
# in
# maar
# ik wil ik jou
# ik heb nooit meer
# ik wil ik
# het is maar ik jou niet omdat ik echt alles gedaan
# ik wil je nu voor mij
# ik heb ik nooit weer
#
#
#
# het is altijd al die
# maar ik nog
# maar
#
#
# een keer
# ik zal altijd naar jou niet maar
#
# ik voel me maar lachen
#
# ik ken jij mij maar even naar mij niet zo goed
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 500 steps reached: generating sample texts.
# ==========
#
# en de zon dan dan is het donker zijn het leven is zo ver dan de zon die is de zon die zijn
#
#
# en de zon weer door de zon weer op de zon
# en je hart is de zon zijn
# tango damango damour
# dan gaat hetango damour
# een keer weer weer op zijn
# deze week weer van jou niet aan de liefde van jou
# jij zal mijn hart die jij weer voor mij<|endoftext|>ik kan mij
# je werd jouw geluk weer uit jou en je me heen
# is voorbij
#
#
#
# een miljoen op jouw gezicht tango damour is tango damourour
# op een nacht
# is de zon die jij bent een schat dans van jouw liefde
# ik zag jij het is mijn hart is zo graag bij me niet meer dan mijn muziek
# in mijn hart is
# ik zal weer als jij
# ik zing me niet meer
# is het meest van jou
# zij die jij van jou nooit meer hoe hetango damour
# maar jij
# als de dans van mij
# in mijn hart
# ik kan
# ik heb jou mijn hart niet zonder jou
#
# die jij me in jouw me de dans van jou
# is het je danst heel even als de liefde en jij
# t
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 600 steps reached: generating sample texts.
# ==========
#  en ik al
# ik ben verliefd
# n hart
# en ik weer op je ben al mijn hart is er altijd bij jou ben ik in dat voor jou
# ik heb me nu echt verliefd
#
# maar je mij alleen
# ik heb mijn hart in mijn leven een ander
# ik ben je nooit meer ben ik toch niet met jou mijn hart niet alleen
# als jij bent voor jou
# ik ben je weet ik hou
# als je bent niet meer
# ik weet ik nooit meer uit
# en je hou alleen alleen
# als ik zijn
# ik wil je niet meer kwijt
# laat me alleen
# want jij niet meer een ander
# ik heb ik nooit meer bent
# laat me niet druk
# als ik jou heb ik me niet
# laat me alleen
# als je hou je nu al mijn hart
# als je mijn leven
# k zou ik weet alleen
#
# als jij me wel alleen
# en ik ook nooit meer kwijt
# als jij me niet meer niet kwijt
# als je mij
# ik wil nooit meer alleen
# de straten
# jij bent
# van de zon ook op hem
# ik dacht ik niet genoeg
# maar ik niet meer te laat
# als ik alleen
# ik weet dat je nooit genoeg
# ik ben toch niets voor altijd niet meer kan ik heb je nooit meer alleen
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 700 steps reached: generating sample texts.
# ==========
#
# de zon pijn
# tot de zon
# op de zon in de zon
#
# en de wolken
# een ster
#
# die de zon
# in de maan
#
#
# en ons
# de wind die stralen
# en de zon in de maan ze stralen
#
# en de zon
#
#
#
#
# en als de zon op de maan hoog in de zee
#
# en de zee met zn hoofd
# tot de zon
# en boven op de zon of de maan
#
# tango damour
#
#
#
#
#
# waar onze liefde
# in de liefde
#
#
# tango damour
# waar onze passie
# tango damour
#
# in ditango damour
# in de nacht
# tango damour
# tango damour
# tango damour
#
# in dit laatste uur
# in een dans van de nacht
# tango damour
# tango damour
# in dit laatste uur
#
#
#
# tango damour
# tango damour
#
# jour
# in de nacht
# tango damour
# tango damour
# tango damour
# tango damour
# tango damour
# bewaarin de liefde van de liefde
# tango damour
# en als een dans van de nacht
#
# tango
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 800 steps reached: generating sample texts.
# ==========
#
# ik had zelf gezien
# ik had ook altijd in jou ik
# maar ik niet
#
# want als een glimlach van mij
# het zou ik dat ik zijn<|endoftext|>als ik niet
#
# als er bent geen afscheid heeft
# de glimlach van het is misschien
# wat zie ik een mooie brieven lees ik weer
# de wereldkaart is
# dat ik ook al die ik zo anders
# maar ik ook vond
# het zou je wel vaak
# de wereldkaarten en ook al mijn laatste mail meer dan sta ik heen zonder jou
# dat ik je niet
# maar dat ik al heb ik niet kwijt
# maar waarom ik nog nooit meer
# maar ik niet
# de wereld lijkt
# maar ik niet meer vergeten
# maar ik daar heb ik nog gezien
#
#
# maar ook misschien ben ik misschien
# dat ik wel meer
#
# ik heb ik het wel
# maar ik heen heb ik nooit kunnen zijn al die ik al heb ik het nooit gezien
# ik heb
# ik kan ook denk ik niet
# maar dat ik soms dat ik toch nooit genoeg
# maar ik dat ik ook heb
# want als ik niet
#
# maar ik het mooiste brieven meer
# ik zou
# ik dacht ik nooit meer
# als ik ook niet
# ik had
# maar ik heb
# toch
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 900 steps reached: generating sample texts.
# ==========
#
#
# jij bent hier
#
#
#
# ik ben mijn hart mijn hart
#
# t is niet waard
#
#
# we gaan met mij nu niet wat ik hou
# maar ik ben bij jou
#
#
# ik ben jij de dag
#
# ik ben jij geen ander
#
#
#
#
# ik wil jou niet dat ik alleen
#
# ik zal voor mij niet krijgen kan nooit gezien
#
#
# ik heb een ander
#
# ik wil je doen
# laat me vrij
# ik wil jou nooit meer gaan
#
#
# ik wil jou niet vergeten
# ik zal mijn leven willen
# geef je nog een beetje met je niet wat ik jou echt nooit meer
#
#
# ik wil ik jou niet vergeten
# k wil met jou nooit alleen bij jou geloven
#
# als ik jou kunnen
#
#
# ik zal nooit meer horen bij jou mijn leven willen geven
#
# ik wil
# ik wil ik nog nooit meer
# zeg mij
# blijf bij jou niet vergeten
# blijf bij mij
# ik zal ik jou niet kwijt
# blijf bij jou
# blijf bij me vrij
# blijf bij mij<|endoftext|>ik wil veel van alles te dromen en ik mis
# blijf bij me bent
#
# blijf bij jou zijn
#
# blijf bij mij
# blijf bij me heen
# blijf bij mij
# ==========
# Configuration saved in ./output\config.json
# Configuration saved in ./output\generation_config.json
# 1,000 steps reached: saving model to /./output
# Model weights saved in ./output\pytorch_model.bin
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,000 steps reached: generating sample texts.
# ==========
#  dat zo is
#
# maar turk vergeet hoe turkie loopt haar geld
# mnooit zal ik ben ik hier nog
# een miljoen op de sterren en de maan
#
#
# en de sterren en de sterren en ik de sterren
# mooie dag
# k hou
#
# k weet ik de sterren en de sterren en de sterren
#
#
#
#
# ik wil met jou en de sterren en de sterren en de sterren en ook van de sterren en de sterren en de sterren en de sterren
# daarom de sterren
#
# t is altijd voor ons lacht de sterren
#
#
# t is de hemel
# het leven is ons lacht de sterren en de maan
# daar heeft ons lacht de sterren en de sterren
# maar telkens weer even
# ik wil ik jou niet meer alleen treur niet meer gaan
# daar vind
# daar kan jou niet vergeten
# al zal de sterren en de sterren en de nacht
#
# de fluit
#
# k heb ik van de sterren en de sterren en de sterren en de sterren en de maan
# en de hemel
# in de hemel met de hele hart
# dus geniet van de sterren
#
# en dan weten in de sterren en de toren door de hemel
# dit leven
# door de toren door de sterren
# en dan de sterren
# dan ik
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,100 steps reached: generating sample texts.
# ==========
#
# maar als het niet heeft dat iemand
#
#
# soms is toch aan jou te trillen
#
#
#
# hou me niet wat het niet van mij zo naar huis
# hou van jou liefde van mij weer heb ik zo van mijn dromen
# hou van mij ik nog altijd van me echt van jou
# hou van mij
# hou van je hou van jou
# hou van mij nu van jou
# hou van mij
# hou van jou
# hou van mij de liefde van mij ik nooit van mij in mij
# hou van jou
# hou van mij niet alleen
# hou van mij een gevoel van mij alleen
# want jij bent en is van liefde
# hou van mij zo van mij is toch zo van mij als je zo van je hou
# hou van mij
# hou van mij is maar voor mij de liefde naar mij ik zo nodig alles gaat
# hou van jou
# hou van mij een zoen
# hou van mij ik van mij ik zo van jou heb ik alleen
# hou van jou
# hou van jou
#
# hou van jou en wil ik dat bent mijn gevoel van jou
# hou van mij alleen
# hou van mij alleen van mij alleen
# hou van mij is van mijalleen van mij zo van mij als jij bent
# hou van mij ik alleen
# hou van mij alleen
# hou van
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,200 steps reached: generating sample texts.
# ==========
#
# eenzaam al een keer
# het is dat ik al te laat
# als ik wil niet dat ik jou te laat
# met jou niet ik niet hier bent
# een beetje dit nu heel even weg
# k wil ik nu niet meer met jou niet meer alleen
# ik wil niet meer
# ik kan ik ook de wereld aan
# een dag in gedachten
# ik wil jou niet
# jij en wil jou nooit meer zonder jou
# ik wil met jou wil je zeggen dat ik wil jou niet meer met jou niet zonder mij
# jij kan jou niet meer zonder jou
# ja ik dat ik dat jij
# een miljoen
# ik wil jou niet zonder jou
# ik wil van jou
# ik wil jou niet zonder jou niet met jou
# zolang ik wil jou
# zolang je geen mens kan ik wil jou nooit meer zonder jou
# een miljoen op non
# een miljoen op aarde en de sterren
#
# een miljoen op me kijkt
# een miljoen
# een miljoen op de maan
# een miljoen op aarde
# een miljoen op aarde
# een miljoen
# een miljoen op aarde
# mn maan dan duizendduizendduizendduizend bloed zweet
# een miljoen
# want ik zo naar jou
# een miljoen
# een miljoen
# een miljoen op de maan
# een miljoen
# een miljoen
# een miljoen
# ze ik zo
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,300 steps reached: generating sample texts.
# ==========
#  kom nooit meer
# maar dat ik heb ik wil nooit alleen nog aan die dromen
# ik heb ik altijd voor jou en voel wat ik zo gelukkig zal
# jij bent
# ik zal niet meer kwijt
# en ik dat is
# jij bent me in mijn leven
# dat ik dat ik ben
# ik wil je voor jou
# jij bent voor een ander
# je bent
# maar ik het moment
# het is voor mij de nacht
# het is voor mij
# jij bent mijn gevoel
# als ik weet
# jij bent nummer een
#
# jij bent voor mij de nacht
# je bent nummer een
# ik kan niet omheen<|endoftext|>het is een
# ik ben ik van de leukste samen
# je bent
# dat gevoel
# het is die blijft altijd blij met jou
# en weet ik de liefde geven
# ik voel dat gevoel
# want dat gevoel
# ik voel me elke dag
# voor ons leven
# jij bent voor mij
# dat gevoel
# dat is en vertrouwen
# dat gevoel
# en dat gevoel
# en ik heb de liefde
# dat gevoel
# dat gevoel
# dat gevoel geeft me elke dag
# dit gevoel
# ik voel voor mij
# het mooiste momenten wat ik het gevoel
# dat gevoel geeft het geluk
# dit gevoel geeft
# maar jou voor ons leven
# maar gevoel geef
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,400 steps reached: generating sample texts.
# ==========
#  t is zo laat
#
# de avond is voor mij zo alleen
# laat mij alleen
# laat me nu stuk
# lekker dansen en de nacht
#
#
#
# laat mij niet alleen maar gaan we dansen en je vrij
# de hele nacht
# en ik zo alleen maar voor jou en ik hou
# laat mij niet alleen vandaag
# want jij en mij daar zo alleen met jou van je hou
# laat je mij in mn hart
# jij geeft mijn hart
# in mn hart
#
# er was niet van je niet alleen een deel van je niet ik alleen maar ik jou wilde van je niet van jou
#
# ik wil jou het maar even voor mij in je hou
#
# t was niet maar een klein beetje wil jou voor mij niet dat je<|endoftext|>k wil je missen
# k wil je
# jij en mij niet
# jij die ander
# k wil niet met jou hier alleen maar van mij in je voor mij
# k wil niet
# en ik jou toch niet
# jij en blijf ik voor mij in de nachten die er leven met jou
#
# jij en mij de nachten
# jij komt voor mij in mn armen
# k wil niet
# k wil niet zonder jou niet alleen van mij in mijn droom ik je
# de winter
# de winter
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,500 steps reached: generating sample texts.
# ==========
#
#
#
# een dag begint de gordijnen zijn
#
# dat jij hier alleen
# want die angst zo lang
# jij geeft niet
#
#
# een dag steeds maar
# jij kan niet bang
#
#
# ik wil je niet vergeten
# jij moet je niet bang zijn
# maar jij deze keer weer gaan
# ik wil je alles zeggen dat gevoel
# jij moet jou niet bang zijn
# jij weet je alles
# jij kan niet zonder jou zijn maar
# nu zijn maar
#
# voorbij jou zijn
# ik tel je alles in jou zijn
# ik zal je niet zonder jou
# jij geeft je alles
# ik kan niet zonder jou zijn
# bij jou zijn
# door jou zijn maar
# ik geef je niet
# jij geeft niet
# nee ik je alles geven
#
# ik moet je alles vergeten
#
# ja ik jou zijn
# toe blijf in jou geloven
#
# ik zie je alles mn liefde
# ja ik je zijn
# op jou zijn
# toe maak dit toch weer aan
# bij jou vandaan
# jij gaf je alles je alles
# toe geef je alles
# want ik dit gaat nooit meer gaan
#
#
# ik kan jou niet zonder jou zijn
# ik wil je alles geven
# ik gaf je alles what je alles wat je alles mocht van je niet kan
#
#
#
# maar ik wil
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,600 steps reached: generating sample texts.
# ==========
#
# het is het toch zo moeilijk
# het is beter dat ik blijf liever alleen te wensen
# ik blijf liever alleen
# het is beter als ik blijf ik blijf je hou me alleen<|endoftext|>jij bent voor altijd altijd altijd altijd altijd altijd altijd trouw
# ik was in de rij bij jou zijn trouw
# jij trouw
# jij bent alles voor altijd trouw
# jij bent echt nooit meer
# dat was voor altijd voor jou
# jij bent trouw
#
# jij bent trouw
# jij bent mn trouw
# jij geeft in de rij bij mij
# en hebt kunnen nu niets voor altijd bij mij
# jij bent mn kracht
#
# je bent mn kracht
# jouw ogen
# jij bent niet
# ik blijf in mijn eigen liedjes
#
# en voor eeuwig trouw
# jij en kom niet van mijn liedjes
# en als een ieder van mij
# en je hou je voor jou
# jij bent als een ieder lied
# ik blijf die je trouw
# dat een ieder lied alleen voor mij
#
# jij bent mn eigen lied
# van jou
# ik blijf steeds trouw
# jij bent mn eigen liedjes
# ik blijf voor altijd bij je zijn<|endoftext|>jij bent zo fijn
# ik blijf in me thuis
# en mijn eigen lied
# dat een ieder lied
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,700 steps reached: generating sample texts.
# ==========
#
# toen ik weer ben ik weer vaak terug
# ik heb er daar geen goud
# ik ben nu goud
# ik blijf haar altijd van goud
# <|endoftext|>ik zal je zeggen dat ik zo graag horen
# met jou gaat bijna uit elkaar
# je bent
# jij maakt mij zo klein
# jij bent mij zo fijn dat ik zo fijn
#
#
# jij bent de liefste van mij
# met jou
# ik zal steeds geven
# jij bent zo graag
# jij bent zo bijzonder dierbaar
# ik kan van mij houden
# dat is zo fijn gevoel
# je bent zo fijn dat ik ben zo fijn verwend
# want liefste morgen
# jij bent zo fijn de liefste van mij de hele leven
# je bent zo fijn
# zonder jou
# ja ik wil jou alles geven
# je bent niet
# met jou kan ik wil jou nooit meer dan echt nooitnee ik van hou van jou
# want je houden
# zeg alsjeblieft
# geen liefde
# geen liefde is echt nooit voorbij
# voel ik al mijn leven
# jij bent nu echt nooit meer kwijt
# ik geeft mijn leven weer
# jij bent mij geluk
# jij maakt me zo belangrijk
# ik geef je geen
# jij bent echt nooit meer voorbij
#
# want dat gevoel
# jij bent mij met alles delen
# jij geeft
# maar tranen
#
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,800 steps reached: generating sample texts.
# ==========
#
# het is dat ik vraag je
# maak wat woorden
# maak me nou
# maak me lach
# maak me lach
# maak me nog altijd
# maak me nog altijd
# maak me nu
# maak me nog altijd
# maak me lach
# maak me nou
# maak me nooit uit
# maak me
# maak me los
# maak me nou
# maak me los
# maak me los
# maak me los
# maak me nou
# maak me lach
# maak me los
# maak me los
# maak me los
# maak me vrij
# maak me los
# maak me vrij
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me kapot
# maak me los
# maak me nog altijd
# maak me los
# maak me los
# maak me nog
# maak me super
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me los
# maak me op
# maak me
# maak me
# maak me
# maak me los
# maak me nog
# maak me los
# maak me
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 1,900 steps reached: generating sample texts.
# ==========
#
#
# ook al die weer eens zal ik jou kunnen vergeten
#
#
# en denk ik door de straten
# maar oh zo weer zal ik geen afscheid nemen
# iedere keer
# jij moet jezelf toch nooit meer gaan
# ik kijk terug
# ik zal altijd bij jou nooit vergeten
# ik zal altijd bij jou kunnen vergeten
# maar je niet meer vergeten
# t zijn maar even
#
# ik zal altijd bij jou willen zeggen
# ik zal altijd bij jou zijn
# ik hoop als jij dat je eens zal zijn
# ik hoop als je iets meer klasse had
#
# jij krijgt van jou voor mij in het leven
# want ik weet nog steeds hetzelfde
# ik wil met jou mn leven delen
# ik wil jou alles opgeven voor jou aan
# jij bent voor mij de manier
# ik wil je alles delen
# ik wil jou het delen
# ik wil jou alles opgeven voor een blik
# het is maar even
# jij bent de grote show
# ik wil jou nu toch wel
# jij bent de kaart
# ook al mn tranen weg ik wil jou nu toch wel aan
#
# jij wordt mijn leven
# ik vraag je dat je wel iets wilde jou nu toch zo aan
# jij wordt mijn leven met jou zo klein
# ik wil je
# ik hoop dat niet meer
# je zei
# ik krijg
# ==========
# Configuration saved in ./output\config.json
# Configuration saved in ./output\generation_config.json
# 2,000 steps reached: saving model to /./output
# Model weights saved in ./output\pytorch_model.bin
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,000 steps reached: generating sample texts.
# ==========
#
# ik heb het al die tijd nu spijt
#
# maar jij hebt me in jouw ogen
# jij krijgt die lach meer van mijn gezicht
# jij krijgt die lach niet van mijn gezicht
# t is mijn gezicht
# ik lach niet van verdriet
# maar tranen die tranen die lacht
# jij krijgt die lach niet van mijn gezicht
# jij krijgt die lach niet van mijn gezicht
# ook al mijn gezicht
# al zie je wel een lach
# maar een lach meer dan een lach
# jij krijgt die lach niet van mijn gezicht
# geen vreugde
# z een glas dat lacht naar dat blauwe ogen
# ik tranen die lacht
# je krijgt die lach niet van mijn gezicht
# dat tranen die lacht
# maar een lach is mijn gezicht
# n tranen
#
#
# het tranen die lacht
# dat tranen die lacht
#
# dat tranen die lacht
# zraagt je blij
# dit is het je gek
# dat tranen die lacht
# de tranen die lacht<|endoftext|>zomaar een plein zomaar een bar
# zomaar wat wijn zomaar in de war
# dat kan voor mij niet
# dit zijn voor mij de allermooiste uren
# het is waar ik voor wil ik voor willen
# het is waar ik voor wil ik mijn tijd
# dat kan voor mij niet lang genoeg gaan duren
# het
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,100 steps reached: generating sample texts.
# ==========
#
# waarom jij er is waarom
# waarom ga je laten staan
# waarom blijf ik van je houden
# waarom blijf ik van je houden
# want ik weet dat ik niet meer bent
# waarom ga je weg
# waarom je toe
# waarom jij er is dat nu voorbij
# dat je me steeds met me meegaat
# waarom ben je me zo eenzaam en zo eenzaam
# waarom moest het zover komen
# maar dat is nu voorbij
# ik hoor nog hoe je lachte
# maar ik weet dat ik niemand wou
# waarom moest het zover komen
# waarom moest het zover komen
# waarom moest het zover komen
# want dit afscheid was voorgoed voorbij
# waarom moest het zover komen
# waarom moest het zover komen
# waarom moet het zover komen
# want zo is het leven
#
# waarom moet het zover komen
# waarom moet het zover komen
# waarom moet het met me meegaan
# waarom heb je het ooit geen zin
# waarom moet ik er is dit ooit voorbij
# waarom moest het zover komen
# maar dat is nu voorbij
#
# waarom moet het ooit voorbij
# waarom moet het ooit geen zin
# waarom moet het met me mee zijn<|endoftext|>als zon verdwijnt de hemel staat
# waar mniemand niemand hier zou mogen zijn
# verloren en alleen zal het weten
# ik neem mn kans
# wat
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,200 steps reached: generating sample texts.
# ==========
#
# ik wil je even met mijn verdriet
# t is beter dat ik nu voorbij
# en elke dag blijf ik je trouw
# jij hoort hier van een engel op aarde
# die je nooit meer vergeten kan
# dat al jouw gezicht
# die je wel herkent
# brengt een engel zo klein
# een die je nooit meer vergeten mag
#
# een die heel klein
# een die heel klein
# een man mag niet meer worden
# een met een
# een meisje van steen
# jij krijgt een engel zo klein
# een meisje van steen
# jij krijgt een lief
# een geen enkele die je zo wil je
# ja echt heel goed
# een die heel klein die je denkt zo heel goed
#
# een die heel klein
# een die heel klein
# een is zo fijn
# een die je denkt
# je hand en lacht naar jou
# de glimlach van een kind
# met soms wel wat verdriet
# een glimlach van een glas
# daar voel je gelukkig
# ook al heb ik geen duit
# en ik snap je nu
# daar kan geen duit
# lalalala
#
# dat nog een glimlach van een vrouw
# dat nog zal nooit meer vergeten
#
# jij krijgt een kans toch wel op een dag
# een morgen
# jij krijgt een heel klein
# ja die ik niet
# ja
# jij weet
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,300 steps reached: generating sample texts.
# ==========
#  geen plaats
# want ik wil ik kan ik niet wachten
# want ik wil kan ik heb je nog steeds weer leven
# en ik wil je zijn
# blijf bij jou
# blijf bij mij
# blijf bij mij
# blijf bij mij
# blijf bij mij
# nee van jou
# blijf bij mij
# blijf bij mij
# blijf bij mij toch blijven
# blijf bij mij
# blijf bij mij
# nee van jou
# we weten
# blijf bij mij
# blijf bij mij toch kom niet weg
# blijf bij mij toch
# blijf bij mij toch blijven
# blijf bij mij
# blijf bij mij
# blijf bij mij
# blijf bij mij
# blijf bij mij
# blijf bij mij
# nee van jou blijf ik hier<|endoftext|>ohoheo
# ohoweeo
# oweeehooo ooooweeo oooo
# ooo oooo ooooweealalalalaloe
# oooweeo oooo oooo
# t stikt hier van de muggen
# in mn haren in mn kleren en ze te horen
# ooo oooo oooo oooo
# ooo oooo oooo ooooweeehoooweeehooo ooooweeehooo
# oo
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,400 steps reached: generating sample texts.
# ==========
#
# met je danst
# dat is niet voor jou
# dat is waar
# tot ik jou in het dal
# in ons hartenlust
# in het vaandel
# we hebben alles ontwikkeld
# in het spel
# en en strijd voor ons kunnen nu hebben anders niet verdiend
# in ons de handen
# een paard en wagen
# en die ons ook beschermen
#
# deze jas maakte van mij een man
# en die je draagt
# en ik voel me zo van goud
#
#
#
# een paard en een is twee
#
# en
# een paard en een hele lelijke jodeljongen
# en ook door wil heen
#
# en en die pijn kan het niet meer tegen
# een paard en een brommen
# een paard en een is twee
# in ons hart willen ze nog meer gebruiken
# en ook zigeuner zijn
# een paard en een zigeuner die horen
# een paard en een zigeuner die horen<|endoftext|>hij was maar een clown
# en zo werd n clown
# in t wit en in t rood
# hij was maar een clown
# en niemand die lach
# in t wit en in t rood
# hij was maar een clown
# maar nu is hij dood
# maar nu is hij dood
# hij dood
# en zo ja wat hij is beroemd
# in t wit en in het bos
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,500 steps reached: generating sample texts.
# ==========
#  nu het weer dat ik jou zou willen
# ik denk nog een keertje aan die vriendschap
#
# je zei me:
# wat ging je me liefhebben is nu stuk
# maar voor jou wil je mij
# ik tel de tijd
#
# en ik jou weer aan jou
# en elke morgen
# ik wil je mij
# maar ga dan zijn
#
# al die eerste zoen
#
#
# daarom valt er een traan
#
#
#
# en als ik jou voel ik mij niet
# ik lach
#
#
#
#
# kom bij mij
# ik wil met jou
# ik houd van jou
#
#
# ik zal voor altijd voor altijd
#
# nietsie
# waar ik van mij
#
# al die tranen van jou
# laat mij altijd voor altijd houden
# niemand die tranen van pijn
#
# ik houd van jou<|endoftext|>elke dag
#
# is als een feest
# de zon
# de liefde straalt een ster zal de hemel straalt stralen
# en als jij straks weer verlaat
# de liefde dat jij straks weer verlaat
# zo is die eenzame uren
# t leven
# er wordt een bijzonder
# maar niemand die hem heeft
#
# dan wordt op je leeftijd
#
# maar niemand die hem heeft op je lang
# de rest ben ik alleen
# de rest ben ik vergeten
#
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,600 steps reached: generating sample texts.
# ==========
#  niet kapot
# je moet gewoon om mij is de afgelopen al ben ik naar de maan
# en als het is
# en alles wat je zegt
# maar in bochten wringt
# en t wordt me weer of je weer even niet dimt
# met soms ook een glas wijn
# en ook een suzie op de dag nog wat ineens zweeg
# maar laten we nog wat blijven
# ik vind het heerlijk hier met jou
# maar laten we nog wat blijven
# he suzie die is misschien voorbij met jou
# kom eens hier toch lekker maf
# kom eens hier en kijk eens gauw
# want die boog met een wow die is misschien voorbij
# kom eens hier en kijk eens gauw
# ik vind het heerlijk hier met jou
# kom eens hier en kijk eens gauw
# denk ik dat we misschien
# kom eens hier en kijk eens gauw
# ik vind het heerlijk hier met jou
# maar ook al weer
# kom eens hier en kijk eens gauw
# kom eens gauw
# want die boog met duizend kleuren
# maar ik zie eens hier gaat dat moment
# he suzie die boog met een meer dan zie
# ik zie de zon en leg
# kom eens hier zitten
# want die boog met duizend kleuren
# die is alleen gemaakt voor jou maar alleen gemaakt voor jou
# toe kijk eens gauw
# maar laten
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,700 steps reached: generating sample texts.
# ==========
#  en ze lokken je van verre
#
# en die liefde is toch je vrienden
# en die doen
# er is je vrienden
# ze zullen altijd voor je zorgen
# er is het je laatste schakel
# wie zijn voor jou
# ik zal er nooit kunnen zijn alsjeblief en leed delen
# ik zal er altijd voor je zorgen
# ook al leef je zo heel anders noemt men jou als je moeder
# je hebt vrienden waarmee je kan
# ze heeft je leven
# en ik zal altijd beminnen
# ik zal je altijd beminnen
# en ik
#
# ik zal altijd voor je zorgen
# ik zal alles vergeten zal altijd voor je zorgen
# ik zal altijd voor je zorgen
# ik zal altijd voor je zorgen
# ik zal altijd voor je zorgen
# ik zal altijd voor je zorgen
# ik zal altijd voor je zorgen
# ik zal altijd voor je zorgen
# ik zal altijd voor jouw zijn
# ik zal altijd voor je zijn
# ik zal altijd voor je zijn
# ook al jouw zijn
# ik zal altijd voor je zorgen
# ik zal altijd voor je zorgen
# ik zal altijd voor jouw zijn als je moeder
# niemand die je beminnen
# niemand die je beminnen
# ik zal altijd beminnen
# ik zal altijd beminnen
# ik zal altijd beminnen
# ik zal altijd beminnen
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,800 steps reached: generating sample texts.
# ==========
#
#
# met een paar daaldraadraad
# een meisje uit de straat
# zelfs het te zien
# ja je krijgt vaak te horen
# maar als je me vader was streek van die jaren
# ach vader was
# jong of oud
# jong of oud je blijft steeds onschuldig
#
#
#
#
# jong of oud je blijft altijd haar kind
#
#
# jong of oud je blijft niet trouw
#
#
# ja vroeg het is zo voorbij
#
# ook al heb ik zelf ingegrepen
#
# een klomp met een scheur ik hem in mn buik
# denk ik haar mijn vader
# dat ik dit niet kwalijk neemt
# het is nu voorbij
# laat een meisje uit de straat
# van
# dat maakt benauwd
# een briefje lag achter het portret van mn kop
# denk ik haar heel even aan hem
# want ik weet waar die verhalen als ik zeg
# mijn moeder kan heel raar doen
# het is helemaal niets voor kerels
# als ik gabber
#
# zijn vader was naar gabber
# deze jas
# gabber
# g toch niet zat in de stront
# brandewijn
# brullend kijk
# gooien totdat ik haar weer in de stront
# op de wallen en als ik r niet wilde
# sta ik naar mn baas toe heb geen tijd
# nu  ik kom
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 2,900 steps reached: generating sample texts.
# ==========
#
# nee wij moeten drie maal gapen
# wij gaan naar lullen
# he sribund door de nacht
#
# de lange avond wacht weer op volgende week
# ja want wij moeten drie maal gapen
#
# dit is zo ver mn moedertje
# dan gaat het is zo ver mn la<|endoftext|>ey hazel
# ik heb hier een hele vieze vaat
# en in de rij
# dat is je vader weer thuis
#
# eerst nog een
# en apart
#
# en apart
# ook al sta je versteld als je zie je denkt hoe ik samen sta
#
# de is het is een heel apart
#
# en apart
# voor een is je samen
#
#
#
# ik was zo alleen
#
# als mijn vader was
#
# oh wat denk ik kan me echt niet verdragen
# ik heb alleen
#
# al is het echt niets ernstigs alleen
# en je houd die ik vanzelf hoe moet ik heen
#
#
# ik zit echt alleen
# vanavond gaan we naar de kermis in de stad
# van de schiettent gaan de kermis in de stad
# van de schiettent gaan van t reuzenrad
# op de kermis daar is altijd wat te doen
# en boven in dat reuzenrad krijg jij een zoen
# lalala
#
#
# van
# ==========
# Configuration saved in ./output\config.json
# Configuration saved in ./output\generation_config.json
# 3,000 steps reached: saving model to /./output
# Model weights saved in ./output\pytorch_model.bin
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,000 steps reached: generating sample texts.
# ==========
#
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijnwanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn<|endoftext|>als je hier ergens op mijn leven
# zie ik dat is net of je daar
# zie ik jouw tranen
# smoves
# zo is het alsof ik straks wil
# wil ik alleen zijn
# heel zacht om jou
# wil ik alleen zijn
# want ik ben smoorverliefd op jou
# maar dat gevoel raak ik er weer
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wil ik alleen zijn
# want ik ben smoorverliefd op jou
# maar dat gevoel raak ik er weer
# wil ik alleen zijnwanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,100 steps reached: generating sample texts.
# ==========
#  de zon voor jou
#
# met je blonde haar
# ongeevenaard de zon voor jou en de zon voor jou
# met je blonde haar
#
#
# ja de mooiste dag
#
# zo een die dag
#
# zo een die dag
#
# met jou
# ik blijf je altijd voor jou
# ja lekker lachen en leef voor jou<|endoftext|>ben even te jong of oud
# want ik verdien
# t is nooit eerder of oud en weg
# maar ik weet niet precies wat ik zou willen weten
# dat zegt mijn vriend
# nu ben je beste vriend verloren
# maar jouw vergeten vriend
# al ben jij niet belangrijk
# maar jouw vergeten vriend
# al ben jij dat heeft ze mij voor het leven
# nu ben jij dat heeft ze niet verdiend
# al ben je aan mn zij
# want ik weet niet meer hoe ik ooit was gezicht
# maar ach jongen je voor mij
# nu ben jij je oud en blijft ook eenzaam en heb ik geld dat is mijn leven
# al ben ik eenzaam en heb ik van binnen
# maar ik voel me houdt me goed
#
#
# desnoods er een dat stilt valt nu nog mis
# maar steeds een dat is mijn eigen schuld
# ik dus niet aan jou vraag maar weg
# ik hoor je nog dikwijls z
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,200 steps reached: generating sample texts.
# ==========
# n opa dat alleen voor haar
# was dat niet
# wat of jij soms ook zeggen
# ik hoef je niet
# ik huil als je moeder je moeder je blijft steeds de les
# het is dat ze jou leerde
# maar ik weet dat zij je niet
# laat ze naar hun eigen kijken
# als hij speelt op zijn ga ik vlieg met mijn vlieger
# tot op een dag
# waar ik ga ik hoor als een wow die dan leest mijn vader
#
# ik wil zweven op de vlucht
# ik ben met jou in mijn leven
#
#
#
#
#
#
# als een vogel zo vrij zo wil ik zijn
# geen enkele traan
#
# de enige die jij wenst
# op een dag een dag een dag
# ik wil een heel klein beetje
#
#
#
# tot dat ik je echt wat jaren steeds hebt vertrouwd
#
# met een beetje dat mag
# met een beetje dat mag
# met een beetje zonneschijn
# wil ik elke dag een beetje beetje meer gaan
#
#
#
#
# wil ik alleen maar bij
# en als je moeder je niet om mee
#
#
# waar ik zo naar zijn
#
#
# ik wil een beetje beetje meer bij jouw zijn<|endoftext|>ik droom van een kerstfeest waar vrede bestaat
# waar ieder gelijk is geen levensdoel
# ze droom
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,300 steps reached: generating sample texts.
# ==========
#
# ja ik wacht niet te wachten
# tot het moment dat we voor altijd samen zijn
# want bij het moment dat je even niet meer komt
#
# ik wil je zeggen dat ik niet kan missen
# ik wil je zeggen dat ik niet kan missen
# ik wil je elke dag een beetje meer
#
# kom bij mij
#
# ik wil je elke dag een beetje meer
#
#
# ik wil je elke dag een beetje meer<|endoftext|>ze maken zelf uit veel woorden heeft ze net zoals jij straks niet bestaan
# de gele licht scheen over jou en de zwarte strand was daar in veel te kort heeft de hand met jou
# maar die mooie momenten die ik jou heb ontmoet
#
# de eerste gezicht van jou is van jou
# de ramen die ik kus en ik kus
# in een heel klein beetje ken
#
# daar bij de zee
# ik wil je meer met zijn tweeen in de zee
# de blauwe zee en de wind
# waar is mijn droom
# met alles wat ik hier vind
# de dagen van jou vind en de wind
# waar is mijn droom
# met alles wat ik hier vind
# de nachten van jou
# ik wil gelukkig zijn
# maar ga je vast
# ik wil je elke dag een beetje meer
#
# ik wil je elke dag een beetje meer
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,400 steps reached: generating sample texts.
# ==========
#
# ik sta hier heel alleen
# de nacht verandert iedereen even kwijt
# onzekerheid je moet je ook geven
# met mn ogen je moet maar kwijt
# er is zoveel te laat
# er is zoveel te laat
# er is zoveel te laat
# er is zoveel te laat
# er is zoveel te laat<|endoftext|>een dan kom je bij me terug
# die huilen tranen weg
# ik moet je niet huilen nee ik moet alleen
# het is nooit meer zonder jou
# voordat ik leef blijf je bij mij
# het is beter dat ik jou vergeet
# want die momenten dat ik eenzaam en alleen ben ik eenzaam
# heb je niemand om mee op je loert mijn blik
# ik heb je nodig alles wordt overbodig
# het had zo mooi kunnen zijn
# als er genoeg liefde krijg je dan nog nooit meer
# ik kijk nog steeds naar de spiegel
# en je kijkt me aan
# we spraken van elkaar
# de een engel in de nacht
# verscheen daar op de gracht
# en vertelde dat er iemand op mij wachten
# en vertelde dat er een stem
# hij was een van die zal vragen
# en die tijd heb nu achter mij gelaten
# want door al die tranen
#
# geeft me steeds weer nieuwe moed
# ik heb me al die momenten dat ik eenzaam en alleen
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,500 steps reached: generating sample texts.
# ==========
# en wat ik me had heb
# dat heb ik jou nog nooit gezien
# schrijf me nooit geen mooie brieven meer
# en leg je bij mn laatste woorden neer
# ik wil niet leven in onzekerheid
# maar dat gevoel raak ik niet kwijt
# je hebt je allerlaatste kans gehad
# ik dacht dat jij wel wat meer klasse had
# maar ook daar heb ik me in vergist
# t is beter dat het over is
# ik voel me vrij
# de wereld lijkt opeens zo anders
# ik ben weer blij
# ik ben van slag
# ja ik heb lopen zoeken
# de liefde kwam heel onverwachts
# het moest beter
# t was nooit meer te jong
# ja ik heb het geluk
# de wereld lijkt ineens zo anders
# ik ben verliefd
# ja ik heb de liefde
# de wereld lijkt ineens zo anders
# ik ben zo blij
# ja ik heb het mooie avontuur wel geen spijt
# je loopt op een keer
#
# ik ben verliefd
#
# oom gebleven
# oom gebleven
# oom
# oom ik het stuurloos
#
# ja ik heb lopen
#
# je hand door
# een en een traan gelaten
# ik dacht dat ik dit wordt
# het moest altijd beter
# ik hoop dat jij dit nog iets goeds voor altijd blijven
#
# iedere avond zie ik ze weer
#
# die je altijd beschermen zouden ze
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,600 steps reached: generating sample texts.
# ==========
#  jij die ik het meest beminis het wat ik het meeste mis
# nu heb ik zelf mn eigen kindren
# denk hoe mijn leven voor me doet
# ik ben toch ook niet vergeten
# een nieuwe dag breekt aan
# vergeet alle mensen
# laat me los het maar weten ze omuipt me pas
# laat me maar weten dat ik niet meer kwijt
# laat me maar weten wat ik ook zeggen
# laat me maar weten wat ik hier toch zeggen
# laat me maar weten
# want als ik een vogel zo vrij zo wil ik zijn
# ja ik wil een leven vol met een ander
# we zijn niet zo n fijn maar toch niemand die me kennen vragen wat is er toch vrij van de kou en dagelijks leef
# ja de mensen ook niet ongelijk
# de enige dag dat ons de vrede geeft
# waar ons de vrede komt
# ik ben die redden laat me vrij
# en moet met me leven
#
# waar ons de mensen ook beschermt
# laat me maar weten wat we ook zeggen
# laat me maar weten wat er komen
# laat me maar weten wat er komen
# laat me maar weten wat er komen
# laat me maar weten wat er komen
# laat me maar weten wat er komen
# laat me maar weten wat er komen
# laat me maar weten wat er komen
# laat
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,700 steps reached: generating sample texts.
# ==========
#
# en dan lach
# wat een dag
#
# jij bent een nacht van me weg
# dag van me weg uur van mn leven
# zon tijd duurt lang zonder jou
# mn verre
#
# zon tijd duurt lang zonder jou
# mn verre
# dag van me weg uur van mn leven
# zon tijd duurt lang zonder jou
# mn verre vrouw
#
# morgen leek n idee
# die morgen ging weg nu niet mee
# die morgen ging weg nu niet mee
#
# jij was vergeefs onderweg
# dag van me weg zonder einde
# morgen leek n idee
# die morgen ging weg nu niet weg
# dag van me weg bleef uit mn leven
# t einde kwam plots zonder jou
# ik was vergeefs onderweg
# lang onderweg weg zonder einde
# t einde kwam plots zonder jou
#
# mn verre vrouw
#
# dag van me weg bleef uit mn leven
# t einde kwam plots zonder jou
# mn verre vrouw<|endoftext|>ik heb eerbied voor jouw grijze haren
# zij bekronen je lieve gezicht
# zij verzachten de sporen der jaren
# na een leven van werken en plicht
# ik heb eerbied voor jouw grijze haren
# zij verzachten de sporen der jaren
# na een leven van werken en plicht
# ik heb eerbied voor jouw grijze haren
# zij bekronen
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,800 steps reached: generating sample texts.
# ==========
#  de zon ook voor ons
# voor altijd gaan schijnen
# dit afscheid dat is maar voor even
# dus droog nu je tranen
# adio amore adio
# jij moet niet huilen
# want eens zal de zon ook voor ons
# voor altijd gaan schijnen
# dit afscheid dat is maar voor even
# dus droog nu je tranen
# adio amore adio
# ik kom terug
# ik zal jou in mij hart
# echt heel goed bewaren
# k neem jou als souvenir
# in mn dromen mee
#
# ook al ben ik ver weg
# ik zal over je waken
# en over n tijdje dan zijn
# net als souvenir
# s avonds ook voor mij
# weer
# jij moet niet huilen
# want eens zal de zon ook voor ons
# voor ons
# dit afscheid dat is maar voor even
# dus droog nu je tranen
# adio amore adio
# ik kom terug
#
#  dagen met jou
# was n groot feest
# zo was mijn avond ik kijk me nog een keer heel even aan
#
# jij moet niet huilen
# want eens zal de zon ook voor ons
# voor ons
# dit afscheid dat is maar voor even
# dus droog nu je tranen
# adio amore adio
# ik kom terug<|endoftext|>ik wil niet van je dromen van je dromen
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 3,900 steps reached: generating sample texts.
# ==========
#
# een hemel met een zon
# en even wordt mn leven
# dan een prachtig mooi chanson
# een lied om van te houden
# een lied dat alles heeft
# een lied dat zegt
# dat zon geluk maar eenmaal wordt beleefd
# ik maak van jouw huis een hemel
# een hemel met een zon
# en even wordt mn leven
# dan een prachtig mooi chanson
# een lied om van te houden
# een lied dat alles heeft
# een lied dat zegt
# dat zon geluk maar eenmaal wordt beleefd
# ik maak van jouw huis een hemel
# een hemel met een zon
# en even wordt mn leven
# dan een prachtig mooi chanson
# een lied om van te houden
# een lied dat alles heeft
# een lied dat zegt
# dat zon geluk maar eenmaal wordt beleefd
# ik maak van jouw huis een hemel
# een hemel met een zon
# en even wordt mn leven
# dan een prachtig mooi chanson
# een lied om van te houden<|endoftext|>verloren liefde verloren dromen
# vanavond ben jij hier niet dicht bij mij
# je zei me dat jij niet terug zou komen
# wat wij hadden is nu allemaal voorbij
# verloren liefde verloren dromen
# waarom ga je nu je nu je maakt toch zoveel stuk
# daarmee heb je zoveel
# ==========
# Configuration saved in ./output\config.json
# Configuration saved in ./output\generation_config.json
# 4,000 steps reached: saving model to /./output
# Model weights saved in ./output\pytorch_model.bin
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,000 steps reached: generating sample texts.
# ==========
#  de hele boel doet
# ik ben te vaak niet kwijt
# ik zeg je meer hoef ik niet
# jouw foto hangt hier nog aan de muur
# jouw blik maakt me nog steeds overstuur
# een boze blik maakt je niet meer geluid dan je wilt
# maar ik weet dat ik mn kansen
# die nog zullen niet dwars worden
# ik zal je missen
# jij ziet je niet staan
# jij zoekt naar jouw geluk
# die eenzaamheid doet me niet pijn
# ik wil je ook al die eenzaamheid
# ik heb het echt gezien
# jij kunt je niet meer alleen
# <|endoftext|>soms denk ik even terug
# maar ik zie het aan ons nu zovele keer je staan
# jij zoekt naar jouw geluk
# maar jij bedoelt niet goed
# dat ik zo graag van me hou zo ontzettend van jou
# jij bent voor mij allebei
# die eenzame uren
# ik heb medelijden voor jouw gouden troon verdiend
#
# maar die tijd heb ik veel te lang voor jou
# zoiets van jou
# na jou
# jij die tijd zal dragen
# ik ben zo eenzaam zonder jou
# voorlang was ik die tijd
# want heel dicht om me heen
# die eenzaamheid deed me zon pijn
# ik ben zo eenzaam en blijf je nooit meer van die dromen
# want die tijd is voor ons
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,100 steps reached: generating sample texts.
# ==========
#
#
# jij laat me dromen elke nacht steeds maar weer krijgen
# mijn hart die tintelt en staat niet meer van je dromen elke nacht meer
#
# zie ik haar benen
# is het alsof ze even belt
# die vraag voor hem staat
#
#
# ik hoor je lach
# ben jij voor de hele wereld van goud
#
# jij bent niet knapmaar je hart is van goud
# dat is wat mij zo naar jou doet verlangen
# een miljoen op de bank t laat me koud
# ik ben zo blij met jou hartje van goud
#
# een miljoen op de bank t laat me koud
# ik ben zo blij met jou hartje van goud
#
# als jij me zo naar me houdt
#
# <|endoftext|>ik laat je nooit meer gaan
# ik wil nooit meer zeggen dat ik van je hou
#
# ik ken een hekel aan die plichten
# voor mij ligt de liefde vindt
# maar ook al heb ik al een hekel aan die plichten
# voor mij is de liefde voor allebei
# heb ik al van de plichten
#
# voor mij is de liefde voor me staat de tijd voor de vrijheid
# en zal je de vele nachten
# want een hekel is pas
#
# ik laat je nooit meer gaan
# ik wil nooit meer kwijt
# griekenland ik wil er niets meer
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,200 steps reached: generating sample texts.
# ==========
#
#
# het is weer hetzelfde lied ome bertus is failliet
# geen ene rooie cent te makken eten uit de vuilnisbakken bijstand wil ie niet
# het is weer hetzelfde lied ome bertus is
# een orginele
#
#
# het is weer hetzelfde lied ome bertus is
#
# het is weer hetzelfde lied ome bertus is
# een orginele makelaar
#
# het is weer hetzelfde lied ome bertus is
# een orginele makelaar
#
# het is weer hetzelfde lied ome bertus is
#
# een orginele makelaar in luchtkastelen
#
# het is weer hetzelfde lied ome bertus is te makken eten uit de vuilnisbakken bijstand wil ie niet
# het is weer hetzelfde lied ome bertus is
# een orginele makelaar in luchtkastelen
#
# het is weer hetzelfde lied ome bertus is
# een orginele makelaar
#
# het is weer hetzelfde lied ome bertus is
# een orginele makelaar in luchtkastelen
#
# het is weer hetzelfde lied ome bertus is
# een orginele makelaar in luchtkastelen heeft zich niet
# maar laten in de luchtkastelen<|endoftext|>ik
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,300 steps reached: generating sample texts.
# ==========
#
#
# ik vind een man
#
# en ik zoek wanhopig
# al mijn zakken na
# naar een nieuw begin
# ik wil naar een nieuw huis
# ik wil naar een mooi paradijs
# ik wil geen goede maar een luxe bakfonds fonds
# maar ik komt er als je mij vraagt
#
# kom in mn armen
# ik wil geen trutje maar een bos niet aan
# k heb genoeg van al te veel
# en overal waar ik ook niet meer van hou
# alleen van mij zo wil ik mijn tijd verspillen<|endoftext|>als de zon verdwijnt de regen
# s nachts ga ik dromend op reis
# ik lig te dromend op de boot
# s nachts vroeg ik
# toe ga je mee
# ik ben op die reis we daar al zo ver weg
# ik ben op die reis we gaan
# als daar een nieuwewetse schuit
# k wil naar een mooi paradijs
# waar onze liefdewaar onze liefde is
#
# echt waar het tussen de wolken
# waar onze liefde is geen spook ik met zijn tweeen op ons twee
# de wind die brengt ons naar ons ideaal
# zonder jou waar de zon gaat dalen dan stopt de karavaan
# waar onze liefde is geen hel
# maar als jij dit nu toch gebeuren zou veel mooier kunnen zijn
# maar als jij een
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,400 steps reached: generating sample texts.
# ==========
#
# maar waar moet ik heen
# in een stad
#
# waar ik mijn bestemming zal openen
# waar ik mijn bestemming aan de haven
# weinig niet meer mensen
# elke dag steeds maar je weet niet meer
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk en tevree
# daar in dat kleine cafe aan de haven
# daar zijn de mensen gelijk
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,500 steps reached: generating sample texts.
# ==========
#
# mijn hart gaat zo voorbij om jou in het leven
# jij geeft mijn leven weer kleur
# ik heb de hele wereld aan jou veroverd
# jij bent de zomer oh ik hou zo van jou
# oh t moet ik jou maar jou
# ik leef mijn droooooahrila
# ik leef mijn drooooheooooo
# k heb t jou me in mijn leven
# ik hou van jou maar wat moet ik toch heen
# ik jou griekenland ik wil mijn geluk dat word jij mijn vrouw
#
# zolang ik leef blijf ik alleen van jou
# ooohohe ronnie
# ik wil naar griekenland ik wil de zon mijn negaat
# oh julia jij word jij mijn vrouw
#
# ik wil naar griekenland ik wil de zon mijn neg
# oh julia jij word jij mijn vrouw
#
# ik wil naar griekenland ik wil de zon mijn neg
# oh julia jij word jij mijn vrouw<|endoftext|>lalalalalala
# ik ging met mijn vrouwtje laatst naar amsterdam
# hejahejaho
# vroeg iemand de weg maar hij keek mij vreemd aan
# hejahejaho
# hij zei nou pardon k weet niet goed wat u zegthejahejaho
# heja
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,600 steps reached: generating sample texts.
# ==========
#  maar even alles gaat zo weer voorbij
# geef me maar een gulle lach dat maakt mij miljonair
# want met duizend kronen daarmee kom je niet zo meer
# want juwelen dragen velen maar geluk dat maakt je blijwant juwelen dragen velen maar geluk dat maakt je blij<|endoftext|>jij bent zo zoet als marseperijss vind ik zo zoet als marsepein
# daarom wil ik zo graag bij je zijn
#
# zit het soms eventjes tegen dan trek je mij er doorheen
# wil ik je daarvoor iets geven omdat ik je voel wat er is soms een feest
# en wil ik zo graag bij je zijn
# want ik heb van jou niets alles gezegd
#
# dat zijn toch die kleine dingen met jou is het leven een feest
#
# en voor mij de mona lisa het allermooiste schilderij
# daarom wil ik zo graag bij je slapen niemand anders
#
# daarom wil ik zo graag bij je zijn
#
# ik wil naar je luisteren op de tv
# of weer een geintje verzinnen jij zet de boel op zijn kop
# jij laat me steeds van je dromen iedere nacht steeds van je horen
#
# jij laat me steeds van je dromen iedere nacht steeds van je horen
#
# jij laat me steeds van je dromen iedere nacht steeds van je houden
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,700 steps reached: generating sample texts.
# ==========
#
# op jou heb ik veel te vaak gezegd
#
# maar dat vertel ik niet dat ik veel heimwee en komt terug
#
# vraag mij niet ik heb verdriet
# ik wil met jou willen praten dansen door de nacht
# maar dat soort dromen komen nooit uit
# k blijf altijd eenzaam
# en toch heb ik nog zoveel te dromen
# zeg mij toe maak je gek van geluk
# een ster zal schijnen over mij
# en als het geluk weer is
# dan een huis
# dan een prachtig mooi chanson
# een lied om van te houden
# een lied dat alles heeft
# een lied dat zegt
# dat zon geluk maar eenmaal wordt beleefd
# ik maak van jou
#
# de liefde en trouw
# jij bent de schat waar k zal
# het laat je niet in mijn hart
# als ik het geluk maar ook de nacht
# het geluk maar eenmaal wordt
# dat ik het zeg
# ik maak van jou
# maar ook al heb ik veel te lang gewacht
#
# er is bij jou
# t is al zolang ik de zee
# geen
# en toch heb ik nog nooit
# k beloofd
#  ik kan er nog zonder jou
# wil ik alleen maar bij je zijn
#
# wanneer ik jou niet krijgen kan
# wil ik alleen zijn
# wanneer ik jou niet krijgen kan
#
# wil ik alleen
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,800 steps reached: generating sample texts.
# ==========
#  een
# ik wil een reactie een keer op mn morgen
# ik kan niet meer vragen hoeveel je van mij houdt
# nu zijn alle dagen zonder jou
# ik droom nog steeds een keertje vast
# t is mn dag vandaag
# k wil n heel klein beetje
# niet veel maar ach dat weet je
# daarom dat ik nu aan jou vraag
# ik wil een keertje vast
# want als je kust alleen maar
# als ons niemand thuis ben
# krijg je niet
# dit keer toch nooit
# de liefde die moet je ondergaan
#
# ik wil nooit meer vragen hoeveel je van mij
# ik wil n ietsie pietsie
# het waait dat rare k wordt elke dag die hier te schrikken
# ooohooohooohooohooho ik kan niet meer stuk
#
# maar ik zing en ik voel mijn alleen
#
# ohohooohooohooohooohooohooho ik kan niet meer stuk
#
# ik wil niet meer denken
# met de vlam in de pijp scheur ik door de brennerpas
# ohooo te kort maar ik schrijf
# met mn dertig tonnen diesel ver van huis maar in mn sas
# met de vlam in de pijp door die eindeloze nacht
# en dan moet ik even denken
# naar mn vrouw die
# ==========
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 4,900 steps reached: generating sample texts.
# ==========
#  dat was de leven
# na een droom
# ik voel me rijk als een bruisend volk
# daar waar iedereen herkent
# daar in ieder gezin
# ik droom van een kerstfeest elke dag weer hetzelfde
# ik droom van een kerstfeest elke dag weer hetzelfde
#
# ja daarop heb ik mn lief
# heel dicht bij jou
# van t pakken bier de pomp
# en 50
# dan iedereen die gaf ik cadeau
# ik heb echt geen rooie duit
#
# ook
# de kelner roept kom op nou mensen
# ut is de hoogste tijd
# ook ik heb mn beste jongen
# want zij weet hoe laat we sluiten
# kom haal patat en drinken
#
# want
# op een avond zie ik de bonas liggen
# de kelner roept kom op nou mensen
# reas op nou mensen
# ut is de hoogste tijd
# ook ik heb mn beste jongen
# want zij weet hoe laat we sluiten nou mensen luister
#
# met een ander
# de
# de
# de term is beun
# beun de hoogste tijd
# u wordt bedankt voor weer n avond gezelligheid
# dag mevrouw en dag meneer
# u komt hier toch weer
#
# de kelner roept kom op nou mensen
# t is de hoogste tijd
# ook ik heb m gezien
# want zij weet hoe laat we sluiten
# kom ik
# ==========
# Configuration saved in ./output\config.json
# Configuration saved in ./output\generation_config.json
# 5,000 steps reached: saving model to /./output
# Model weights saved in ./output\pytorch_model.bin
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.4"
# }
# 5,000 steps reached: generating sample texts.
# `Trainer.fit` stopped: `max_steps=5000` reached.
# ==========
#
# en in een ruk een struikelt met zn allen de   tien keer op en neer
# vier mooie stukken borreltje met een haakie op zak
# daar zit ie met een snuitje
# en staart voor zich uit
#
# ze blijven maar over
#
# en ze denken komme uit de kuiper wordt een heel klein beetje dikker en koud
# en wordt al lang door de woltseme
# en elke avond achter t raam
#
# dan heeft de dag weer stil te staan
# als jongetje dat later
# een zeeman wou zijn
#
# ik denk zo vaak aan
# denk hoe hij was
# maar dat later
# zei hij vader ga je mee
# en die patsy ze kwam weleens hier
# voor zijn kamer
# met dat meisje was ik t is niet erg om hier
# een schoonmaakartieste en een heel klein
# en later komt een dag te vroeg
# kom bij mij laat
# en ziet is er een amsterdammer want amsterdam
# je bent nog net als toen
#
# en kom je terug na heel wat jaren zeggen ze me heten democratie
# maar het leven gaat zo niet zonder rust
# je komt dit niet s avonds jeledjes liggen in t portiek
# en als mokum<|endoftext|>vaak de forp en amsterdam
# ==========
# Configuration saved in ./output\config.json
# Configuration saved in ./output\generation_config.json
# Model weights saved in ./output\pytorch_model.bin
